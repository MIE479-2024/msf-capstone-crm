# %%
from main import LoanClassifier

# %%
classifier = LoanClassifier(
    data_path = './sample_data/2023Q1_stat.csv',
    labelled = True
)
# Out:
# d:\capstone\msf-capstone-crm\loanclassifier\main.py:12: DtypeWarning: Columns (39,40,41,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.data = pd.read_csv(data_path, index_col="LOAN_ID")
# d:\capstone\msf-capstone-crm\loanclassifier\utils\non_woe_preparation.py:51: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   table['FTHB_FLAG'] = table['FTHB_FLAG'].replace({'Y': 1, 'N': 0})
# (CVXPY) Dec 01 10:50:03 AM: Encountered unexpected exception importing solver GLOP:
# RuntimeError('Unrecognized new version of ortools (9.11.4210). Expected < 9.10.0. Please open a feature request on cvxpy to enable support for this version.')
# (CVXPY) Dec 01 10:50:03 AM: Encountered unexpected exception importing solver PDLP:
# RuntimeError('Unrecognized new version of ortools (9.11.4210). Expected < 9.10.0. Please open a feature request on cvxpy to enable support for this version.')

# %%
classifier.evaluate()
# Out:
# d:\capstone\msf-capstone-crm\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [10:50:04] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\data\../common/error_msg.h:80: If you are loading a serialized model (like pickle in Python, RDS in R) or
# configuration generated by an older version of XGBoost, please export the model by calling
# `Booster.save_model` from that version first, then load it back in current version. See:
#
#     https://xgboost.readthedocs.io/en/stable/tutorials/saving_model.html
#
# for more details about differences between saving model and serializing.
#
#   warnings.warn(smsg, UserWarning)

# %%
classifier.roc_curve
# Out:
# (<Figure size 3000x2400 with 1 Axes>,
#  <Axes: title={'center': 'ROC Curves'}, xlabel='False Positive Rate', ylabel='True Positive Rate'>)

# %%
classifier.predictions
# Out:
#            linear_svm_3f_woe.pkl_Predicted_Probabilities  \
# LOAN_ID
# 135176712                                       0.386810
# 135176713                                       0.488644
# 135176714                                       0.411607
# 135176715                                       0.463161
# 135176716                                       0.624069
# ...                                                  ...
# 135887963                                       0.490593
# 135887964                                       0.394364
# 135887965                                       0.609398
# 135887966                                       0.467513
# 135887968                                       0.388128
#
#            linear_svm_3f_woe.pkl_Predicted_Classes  \
# LOAN_ID
# 135176712                                        0
# 135176713                                        0
# 135176714                                        0
# 135176715                                        0
# 135176716                                        1
# ...                                            ...
# 135887963                                        0
# 135887964                                        0
# 135887965                                        1
# 135887966                                        0
# 135887968                                        0
#
#            linear_svm_2021.pkl_Predicted_Probabilities  \
# LOAN_ID
# 135176712                                     0.313480
# 135176713                                     0.443867
# 135176714                                     0.267933
# 135176715                                     0.450030
# 135176716                                     0.626411
# ...                                                ...
# 135887963                                     0.358680
# 135887964                                     0.379724
# 135887965                                     0.528336
# 135887966                                     0.399725
# 135887968                                     0.287354
#
#            linear_svm_2021.pkl_Predicted_Classes  \
# LOAN_ID
# 135176712                                      0
# 135176713                                      0
# 135176714                                      0
# 135176715                                      0
# 135176716                                      1
# ...                                          ...
# 135887963                                      0
# 135887964                                      0
# 135887965                                      1
# 135887966                                      0
# 135887968                                      0
#
#            log_reg_3f_woe.pkl_Predicted_Probabilities  \
# LOAN_ID
# 135176712                                    0.245701
# 135176713                                    0.463533
# 135176714                                    0.299243
# 135176715                                    0.420909
# 135176716                                    0.766101
# ...                                               ...
# 135887963                                    0.461375
# 135887964                                    0.252513
# 135887965                                    0.757196
# 135887966                                    0.424887
# 135887968                                    0.253528
#
#            log_reg_3f_woe.pkl_Predicted_Classes  \
# LOAN_ID
# 135176712                                     0
# 135176713                                     0
# 135176714                                     0
# 135176715                                     0
# 135176716                                     1
# ...                                         ...
# 135887963                                     0
# 135887964                                     0
# 135887965                                     1
# 135887966                                     0
# 135887968                                     0
#
#            xgboost_2021.pkl_Predicted_Probabilities  \
# LOAN_ID
# 135176712                                  0.054149
# 135176713                                  0.320831
# 135176714                                  0.016453
# 135176715                                  0.151092
# 135176716                                  0.749965
# ...                                             ...
# 135887963                                  0.118729
# 135887964                                  0.074515
# 135887965                                  0.578976
# 135887966                                  0.248151
# 135887968                                  0.035695
#
#            xgboost_2021.pkl_Predicted_Classes
# LOAN_ID
# 135176712                                   0
# 135176713                                   0
# 135176714                                   0
# 135176715                                   0
# 135176716                                   1
# ...                                       ...
# 135887963                                   0
# 135887964                                   0
# 135887965                                   1
# 135887966                                   0
# 135887968                                   0
#
# [196349 rows x 8 columns]

# %%
classifier.classification_report
# Out:
#                        Class       AUC  Accuracy    Recall  Precision  \
# Model
# linear_svm_3f_woe.pkl      0  0.757334  0.475067  0.472171   0.998016
# linear_svm_3f_woe.pkl      1  0.757334  0.475067  0.871489   0.011918
# linear_svm_2021.pkl        0  0.793427  0.743462  0.743886   0.996920
# linear_svm_2021.pkl        1  0.793427  0.743462  0.685393   0.019175
# log_reg_3f_woe.pkl         0  0.756248  0.433198  0.429878   0.998094
# log_reg_3f_woe.pkl         1  0.756248  0.433198  0.887640   0.011246
# xgboost_2021.pkl           0  0.758078  0.864023  0.867057   0.995377
# xgboost_2021.pkl           1  0.758078  0.864023  0.448736   0.024065
#
#                        F1-Score
# Model
# linear_svm_3f_woe.pkl  0.641054
# linear_svm_3f_woe.pkl  0.023514
# linear_svm_2021.pkl    0.852013
# linear_svm_2021.pkl    0.037307
# log_reg_3f_woe.pkl     0.600934
# log_reg_3f_woe.pkl     0.022211
# xgboost_2021.pkl       0.926796
# xgboost_2021.pkl       0.045680

# %%
nl_classifier = LoanClassifier(
    data_path = './sample_data/2023Q1_stat.csv',
    labelled = False
)
# Out:
# d:\capstone\msf-capstone-crm\loanclassifier\main.py:12: DtypeWarning: Columns (39,40,41,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.data = pd.read_csv(data_path, index_col="LOAN_ID")
# d:\capstone\msf-capstone-crm\loanclassifier\utils\non_woe_preparation.py:51: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   table['FTHB_FLAG'] = table['FTHB_FLAG'].replace({'Y': 1, 'N': 0})

# %%
nl_classifier.evaluate()

# %%
nl_classifier.classification_report
# Out:
#                        Total Loans  Non-Default  Default  Default Percentage
# Model
# linear_svm_3f_woe.pkl       210810       111288    99522               47.21
# linear_svm_2021.pkl         210810        54754   156056               74.03
# log_reg_3f_woe.pkl          210810       119915    90895               43.12
# xgboost_2021.pkl            210810        28596   182214               86.44

# %%
nl_classifier.predictions
# Out:
#            linear_svm_3f_woe.pkl_Predicted_Probabilities  \
# LOAN_ID
# 135176712                                       0.386810
# 135176713                                       0.488644
# 135176714                                       0.411607
# 135176715                                       0.463161
# 135176716                                       0.624069
# ...                                                  ...
# 135887964                                       0.394364
# 135887965                                       0.609398
# 135887966                                       0.467513
# 135887967                                       0.371804
# 135887968                                       0.388128
#
#            linear_svm_3f_woe.pkl_Predicted_Classes  \
# LOAN_ID
# 135176712                                        0
# 135176713                                        0
# 135176714                                        0
# 135176715                                        0
# 135176716                                        1
# ...                                            ...
# 135887964                                        0
# 135887965                                        1
# 135887966                                        0
# 135887967                                        0
# 135887968                                        0
#
#            linear_svm_2021.pkl_Predicted_Probabilities  \
# LOAN_ID
# 135176712                                     0.314451
# 135176713                                     0.443956
# 135176714                                     0.268631
# 135176715                                     0.450531
# 135176716                                     0.623704
# ...                                                ...
# 135887964                                     0.380452
# 135887965                                     0.528045
# 135887966                                     0.400134
# 135887967                                     0.295010
# 135887968                                     0.288377
#
#            linear_svm_2021.pkl_Predicted_Classes  \
# LOAN_ID
# 135176712                                      0
# 135176713                                      0
# 135176714                                      0
# 135176715                                      0
# 135176716                                      1
# ...                                          ...
# 135887964                                      0
# 135887965                                      1
# 135887966                                      0
# 135887967                                      0
# 135887968                                      0
#
#            log_reg_3f_woe.pkl_Predicted_Probabilities  \
# LOAN_ID
# 135176712                                    0.245701
# 135176713                                    0.463533
# 135176714                                    0.299243
# 135176715                                    0.420909
# 135176716                                    0.766101
# ...                                               ...
# 135887964                                    0.252513
# 135887965                                    0.757196
# 135887966                                    0.424887
# 135887967                                    0.216095
# 135887968                                    0.253528
#
#            log_reg_3f_woe.pkl_Predicted_Classes  \
# LOAN_ID
# 135176712                                     0
# 135176713                                     0
# 135176714                                     0
# 135176715                                     0
# 135176716                                     1
# ...                                         ...
# 135887964                                     0
# 135887965                                     1
# 135887966                                     0
# 135887967                                     0
# 135887968                                     0
#
#            xgboost_2021.pkl_Predicted_Probabilities  \
# LOAN_ID
# 135176712                                  0.054149
# 135176713                                  0.282367
# 135176714                                  0.015968
# 135176715                                  0.151092
# 135176716                                  0.749965
# ...                                             ...
# 135887964                                  0.080064
# 135887965                                  0.578976
# 135887966                                  0.264041
# 135887967                                  0.082906
# 135887968                                  0.035695
#
#            xgboost_2021.pkl_Predicted_Classes
# LOAN_ID
# 135176712                                   0
# 135176713                                   0
# 135176714                                   0
# 135176715                                   0
# 135176716                                   1
# ...                                       ...
# 135887964                                   0
# 135887965                                   1
# 135887966                                   0
# 135887967                                   0
# 135887968                                   0
#
# [210810 rows x 8 columns]

# %%
nl_classifier.roc_curve
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 nl_classifier.roc_curve
#
# File d:\capstone\msf-capstone-crm\loanclassifier\main.py:56, in LoanClassifier.roc_curve(self)
#      53 @property
#      54 def roc_curve(self):
#      55     if not self.labelled:
# ---> 56         raise RuntimeError("ROC Curve is only available for labelled data, i.e. loan data with performance variables.")
#      58     if not self.models_evaluated:
#      59         raise RuntimeError("ROC Curve is not available until models are evaluated. To evaluate selected classifiers, first call .evaluate().")
#
# RuntimeError: ROC Curve is only available for labelled data, i.e. loan data with performance variables.
